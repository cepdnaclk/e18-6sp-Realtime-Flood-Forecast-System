# %% [markdown]
# # connect database and create dataframe

# %%
# !pip uninstall pymongo
# !pip install pymongo[srv]
# Out:
# WARNING: Skipping pymongo as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymongo[srv]
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 20.1 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 34.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.3.0 pymongo-4.3.3

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.grid'] = False

# %%
import pymongo as pym
import pandas as pd
from sklearn.model_selection import train_test_split

MongoDB_URI = 'mongodb+srv://admin:e186sp@cluster0.rrsscwc.mongodb.net/?retryWrites=true&w=majority'

client = pym.MongoClient(MongoDB_URI) #connect database
client.test
# Out:
# Database(MongoClient(host=['ac-wv1bysg-shard-00-00.rrsscwc.mongodb.net:27017', 'ac-wv1bysg-shard-00-01.rrsscwc.mongodb.net:27017', 'ac-wv1bysg-shard-00-02.rrsscwc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-hev5w6-shard-0', tls=True), 'test')

# %%
db = client.FFSML
collection = db.ML_Data

df = pd.DataFrame(list(collection.find()))

df.drop(columns=['_id'],inplace=True) #drop _id column

#col_names = ['attaragalla_rf','galgamuwa_rf','mediyawa_rf','mahagalkadawala_rf','streamflow','Date']
col_names = ['year','month','day','attaragalla_rf','galgamuwa_rf','mediyawa_rf','mahagalkadawala_rf','streamflow']
df.columns = col_names
df.head()
# Out:
#    year  month  day  attaragalla_rf  galgamuwa_rf  mediyawa_rf  \
# 0  2016      1    2             0.0          25.0         19.5
# 1  2016      1    3             0.0           0.0          0.0
# 2  2016      1    1             0.0           7.6         12.3
# 3  2016      1    7             0.0           0.0          4.1
# 4  2016      1   10             0.0           0.0          0.0
#
#    mahagalkadawala_rf  streamflow
# 0                 0.0   17.981640
# 1                 0.0    3.913854
# 2                 8.6    5.810550
# 3                 0.0    3.081524
# 4                 0.0    1.986926

# %% [markdown]
# # Data spliting

# %%
from sklearn.model_selection import train_test_split

Y = df['streamflow']
X = df.drop(['streamflow'],axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)


print(X_train.shape)
print(X_test.shape)
print(X_val.shape)

print(X.columns)
# Out:
# (1051, 7)
# (293, 7)
# (117, 7)
# Index(['year', 'month', 'day', 'attaragalla_rf', 'galgamuwa_rf', 'mediyawa_rf',
#        'mahagalkadawala_rf'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# define min max scaler
scaler = MinMaxScaler()

# transform data
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %% [markdown]
# # LSTM

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredLogarithmicError


learning_rate = 0.01

# Build the LSTM model
model = Sequential()
model.add(LSTM(7, input_shape=(X_train.shape[1], 1), return_sequences=True))
model.add(LSTM(7, return_sequences=True))
model.add(LSTM(7, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

msle = MeanSquaredLogarithmicError()
model.compile(loss=msle, optimizer='adam', metrics=[msle])

# %%
# Train the model
history = model.fit(x=X_train, y=y_train.values,
                    validation_data=(X_val, y_val.values),
                    batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 8s 42ms/step - loss: 0.3176 - mean_squared_logarithmic_error: 0.3178 - val_loss: 0.4498 - val_mean_squared_logarithmic_error: 0.4412
# Epoch 2/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.3172 - mean_squared_logarithmic_error: 0.3166 - val_loss: 0.4485 - val_mean_squared_logarithmic_error: 0.4399
# Epoch 3/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.3169 - mean_squared_logarithmic_error: 0.3159 - val_loss: 0.4457 - val_mean_squared_logarithmic_error: 0.4372
# Epoch 4/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.3161 - mean_squared_logarithmic_error: 0.3155 - val_loss: 0.4439 - val_mean_squared_logarithmic_error: 0.4354
# Epoch 5/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.3151 - mean_squared_logarithmic_error: 0.3144 - val_loss: 0.4379 - val_mean_squared_logarithmic_error: 0.4294
# Epoch 6/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.3139 - mean_squared_logarithmic_error: 0.3132 - val_loss: 0.4364 - val_mean_squared_logarithmic_error: 0.4279
# Epoch 7/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.3097 - mean_squared_logarithmic_error: 0.3105 - val_loss: 0.4324 - val_mean_squared_logarithmic_error: 0.4239
# Epoch 8/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.3032 - mean_squared_logarithmic_error: 0.3052 - val_loss: 0.4225 - val_mean_squared_logarithmic_error: 0.4138
# Epoch 9/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2946 - mean_squared_logarithmic_error: 0.2943 - val_loss: 0.4147 - val_mean_squared_logarithmic_error: 0.4064
# Epoch 10/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.2860 - mean_squared_logarithmic_error: 0.2853 - val_loss: 0.3991 - val_mean_squared_logarithmic_error: 0.3897
# Epoch 11/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2832 - mean_squared_logarithmic_error: 0.2836 - val_loss: 0.3927 - val_mean_squared_logarithmic_error: 0.3844
# Epoch 12/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2767 - mean_squared_logarithmic_error: 0.2761 - val_loss: 0.3887 - val_mean_squared_logarithmic_error: 0.3784
# Epoch 13/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2769 - mean_squared_logarithmic_error: 0.2764 - val_loss: 0.3824 - val_mean_squared_logarithmic_error: 0.3724
# Epoch 14/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2711 - mean_squared_logarithmic_error: 0.2702 - val_loss: 0.3778 - val_mean_squared_logarithmic_error: 0.3707
# Epoch 15/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2693 - mean_squared_logarithmic_error: 0.2683 - val_loss: 0.3870 - val_mean_squared_logarithmic_error: 0.3820
# Epoch 16/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2663 - mean_squared_logarithmic_error: 0.2663 - val_loss: 0.3732 - val_mean_squared_logarithmic_error: 0.3634
# Epoch 17/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2645 - mean_squared_logarithmic_error: 0.2640 - val_loss: 0.3690 - val_mean_squared_logarithmic_error: 0.3595
# Epoch 18/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2635 - mean_squared_logarithmic_error: 0.2625 - val_loss: 0.3629 - val_mean_squared_logarithmic_error: 0.3556
# Epoch 19/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2600 - mean_squared_logarithmic_error: 0.2595 - val_loss: 0.3681 - val_mean_squared_logarithmic_error: 0.3624
# Epoch 20/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2578 - mean_squared_logarithmic_error: 0.2581 - val_loss: 0.3605 - val_mean_squared_logarithmic_error: 0.3526
# Epoch 21/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2587 - mean_squared_logarithmic_error: 0.2578 - val_loss: 0.3606 - val_mean_squared_logarithmic_error: 0.3543
# Epoch 22/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2563 - mean_squared_logarithmic_error: 0.2555 - val_loss: 0.3695 - val_mean_squared_logarithmic_error: 0.3646
# Epoch 23/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2546 - mean_squared_logarithmic_error: 0.2563 - val_loss: 0.3572 - val_mean_squared_logarithmic_error: 0.3507
# Epoch 24/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2527 - mean_squared_logarithmic_error: 0.2550 - val_loss: 0.3601 - val_mean_squared_logarithmic_error: 0.3542
# Epoch 25/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2519 - mean_squared_logarithmic_error: 0.2510 - val_loss: 0.3705 - val_mean_squared_logarithmic_error: 0.3653
# Epoch 26/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2517 - mean_squared_logarithmic_error: 0.2510 - val_loss: 0.3532 - val_mean_squared_logarithmic_error: 0.3460
# Epoch 27/100
# 33/33 [==============================] - 0s 11ms/step - loss: 0.2500 - mean_squared_logarithmic_error: 0.2502 - val_loss: 0.3650 - val_mean_squared_logarithmic_error: 0.3596
# Epoch 28/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2492 - mean_squared_logarithmic_error: 0.2498 - val_loss: 0.3518 - val_mean_squared_logarithmic_error: 0.3448
# Epoch 29/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.2472 - mean_squared_logarithmic_error: 0.2475 - val_loss: 0.3545 - val_mean_squared_logarithmic_error: 0.3484
# Epoch 30/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.2458 - mean_squared_logarithmic_error: 0.2458 - val_loss: 0.3566 - val_mean_squared_logarithmic_error: 0.3511
# Epoch 31/100
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2453 - mean_squared_logarithmic_error: 0.2445 - val_loss: 0.3518 - val_mean_squared_logarithmic_error: 0.3453
# Epoch 32/100
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2436 - mean_squared_logarithmic_error: 0.2429 - val_loss: 0.3482 - val_mean_squared_logarithmic_error: 0.3415
# Epoch 33/100
# 33/33 [==============================] - 0s 15ms/step - loss: 0.2416 - mean_squared_logarithmic_error: 0.2418 - val_loss: 0.3499 - val_mean_squared_logarithmic_error: 0.3437
# Epoch 34/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2411 - mean_squared_logarithmic_error: 0.2403 - val_loss: 0.3496 - val_mean_squared_logarithmic_error: 0.3438
# Epoch 35/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2408 - mean_squared_logarithmic_error: 0.2417 - val_loss: 0.3479 - val_mean_squared_logarithmic_error: 0.3419
# Epoch 36/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2394 - mean_squared_logarithmic_error: 0.2388 - val_loss: 0.3462 - val_mean_squared_logarithmic_error: 0.3399
# Epoch 37/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2384 - mean_squared_logarithmic_error: 0.2380 - val_loss: 0.3513 - val_mean_squared_logarithmic_error: 0.3456
# Epoch 38/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2396 - mean_squared_logarithmic_error: 0.2412 - val_loss: 0.3463 - val_mean_squared_logarithmic_error: 0.3403
# Epoch 39/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2373 - mean_squared_logarithmic_error: 0.2365 - val_loss: 0.3462 - val_mean_squared_logarithmic_error: 0.3399
# Epoch 40/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2369 - mean_squared_logarithmic_error: 0.2380 - val_loss: 0.3432 - val_mean_squared_logarithmic_error: 0.3366
# Epoch 41/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2363 - mean_squared_logarithmic_error: 0.2367 - val_loss: 0.3450 - val_mean_squared_logarithmic_error: 0.3388
# Epoch 42/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2369 - mean_squared_logarithmic_error: 0.2364 - val_loss: 0.3434 - val_mean_squared_logarithmic_error: 0.3370
# Epoch 43/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2372 - mean_squared_logarithmic_error: 0.2387 - val_loss: 0.3408 - val_mean_squared_logarithmic_error: 0.3334
# Epoch 44/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2346 - mean_squared_logarithmic_error: 0.2338 - val_loss: 0.3501 - val_mean_squared_logarithmic_error: 0.3448
# Epoch 45/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2367 - mean_squared_logarithmic_error: 0.2358 - val_loss: 0.3461 - val_mean_squared_logarithmic_error: 0.3403
# Epoch 46/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2341 - mean_squared_logarithmic_error: 0.2342 - val_loss: 0.3404 - val_mean_squared_logarithmic_error: 0.3335
# Epoch 47/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2342 - mean_squared_logarithmic_error: 0.2342 - val_loss: 0.3446 - val_mean_squared_logarithmic_error: 0.3385
# Epoch 48/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2341 - mean_squared_logarithmic_error: 0.2339 - val_loss: 0.3409 - val_mean_squared_logarithmic_error: 0.3342
# Epoch 49/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2349 - mean_squared_logarithmic_error: 0.2346 - val_loss: 0.3441 - val_mean_squared_logarithmic_error: 0.3381
# Epoch 50/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2337 - mean_squared_logarithmic_error: 0.2334 - val_loss: 0.3449 - val_mean_squared_logarithmic_error: 0.3389
# Epoch 51/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2331 - mean_squared_logarithmic_error: 0.2331 - val_loss: 0.3431 - val_mean_squared_logarithmic_error: 0.3371
# Epoch 52/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2332 - mean_squared_logarithmic_error: 0.2338 - val_loss: 0.3394 - val_mean_squared_logarithmic_error: 0.3322
# Epoch 53/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2328 - mean_squared_logarithmic_error: 0.2321 - val_loss: 0.3417 - val_mean_squared_logarithmic_error: 0.3355
# Epoch 54/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2330 - mean_squared_logarithmic_error: 0.2322 - val_loss: 0.3445 - val_mean_squared_logarithmic_error: 0.3385
# Epoch 55/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2322 - mean_squared_logarithmic_error: 0.2337 - val_loss: 0.3414 - val_mean_squared_logarithmic_error: 0.3350
# Epoch 56/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2321 - mean_squared_logarithmic_error: 0.2318 - val_loss: 0.3417 - val_mean_squared_logarithmic_error: 0.3358
# Epoch 57/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2324 - mean_squared_logarithmic_error: 0.2357 - val_loss: 0.3390 - val_mean_squared_logarithmic_error: 0.3324
# Epoch 58/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2311 - mean_squared_logarithmic_error: 0.2308 - val_loss: 0.3414 - val_mean_squared_logarithmic_error: 0.3351
# Epoch 59/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2314 - mean_squared_logarithmic_error: 0.2317 - val_loss: 0.3412 - val_mean_squared_logarithmic_error: 0.3349
# Epoch 60/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2311 - mean_squared_logarithmic_error: 0.2303 - val_loss: 0.3396 - val_mean_squared_logarithmic_error: 0.3330
# Epoch 61/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2315 - mean_squared_logarithmic_error: 0.2310 - val_loss: 0.3405 - val_mean_squared_logarithmic_error: 0.3340
# Epoch 62/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2312 - mean_squared_logarithmic_error: 0.2313 - val_loss: 0.3385 - val_mean_squared_logarithmic_error: 0.3315
# Epoch 63/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2321 - mean_squared_logarithmic_error: 0.2322 - val_loss: 0.3389 - val_mean_squared_logarithmic_error: 0.3322
# Epoch 64/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2310 - mean_squared_logarithmic_error: 0.2333 - val_loss: 0.3374 - val_mean_squared_logarithmic_error: 0.3304
# Epoch 65/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2325 - mean_squared_logarithmic_error: 0.2317 - val_loss: 0.3370 - val_mean_squared_logarithmic_error: 0.3298
# Epoch 66/100
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2306 - mean_squared_logarithmic_error: 0.2309 - val_loss: 0.3365 - val_mean_squared_logarithmic_error: 0.3297
# Epoch 67/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.2316 - mean_squared_logarithmic_error: 0.2316 - val_loss: 0.3379 - val_mean_squared_logarithmic_error: 0.3311
# Epoch 68/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.2305 - mean_squared_logarithmic_error: 0.2298 - val_loss: 0.3367 - val_mean_squared_logarithmic_error: 0.3297
# Epoch 69/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2302 - mean_squared_logarithmic_error: 0.2297 - val_loss: 0.3398 - val_mean_squared_logarithmic_error: 0.3338
# Epoch 70/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2299 - mean_squared_logarithmic_error: 0.2291 - val_loss: 0.3403 - val_mean_squared_logarithmic_error: 0.3340
# Epoch 71/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2295 - mean_squared_logarithmic_error: 0.2287 - val_loss: 0.3360 - val_mean_squared_logarithmic_error: 0.3290
# Epoch 72/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.2289 - mean_squared_logarithmic_error: 0.2286 - val_loss: 0.3440 - val_mean_squared_logarithmic_error: 0.3385
# Epoch 73/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2289 - mean_squared_logarithmic_error: 0.2280 - val_loss: 0.3339 - val_mean_squared_logarithmic_error: 0.3260
# Epoch 74/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2301 - mean_squared_logarithmic_error: 0.2293 - val_loss: 0.3351 - val_mean_squared_logarithmic_error: 0.3281
# Epoch 75/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2300 - mean_squared_logarithmic_error: 0.2293 - val_loss: 0.3400 - val_mean_squared_logarithmic_error: 0.3339
# Epoch 76/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2303 - mean_squared_logarithmic_error: 0.2294 - val_loss: 0.3375 - val_mean_squared_logarithmic_error: 0.3311
# Epoch 77/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2291 - mean_squared_logarithmic_error: 0.2283 - val_loss: 0.3343 - val_mean_squared_logarithmic_error: 0.3269
# Epoch 78/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2302 - mean_squared_logarithmic_error: 0.2295 - val_loss: 0.3362 - val_mean_squared_logarithmic_error: 0.3295
# Epoch 79/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2297 - mean_squared_logarithmic_error: 0.2309 - val_loss: 0.3433 - val_mean_squared_logarithmic_error: 0.3376
# Epoch 80/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2289 - mean_squared_logarithmic_error: 0.2288 - val_loss: 0.3343 - val_mean_squared_logarithmic_error: 0.3272
# Epoch 81/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2286 - mean_squared_logarithmic_error: 0.2289 - val_loss: 0.3387 - val_mean_squared_logarithmic_error: 0.3327
# Epoch 82/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2290 - mean_squared_logarithmic_error: 0.2286 - val_loss: 0.3348 - val_mean_squared_logarithmic_error: 0.3280
# Epoch 83/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2286 - mean_squared_logarithmic_error: 0.2280 - val_loss: 0.3336 - val_mean_squared_logarithmic_error: 0.3265
# Epoch 84/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2296 - mean_squared_logarithmic_error: 0.2290 - val_loss: 0.3327 - val_mean_squared_logarithmic_error: 0.3253
# Epoch 85/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2275 - mean_squared_logarithmic_error: 0.2267 - val_loss: 0.3391 - val_mean_squared_logarithmic_error: 0.3332
# Epoch 86/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2281 - mean_squared_logarithmic_error: 0.2279 - val_loss: 0.3348 - val_mean_squared_logarithmic_error: 0.3277
# Epoch 87/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2297 - mean_squared_logarithmic_error: 0.2289 - val_loss: 0.3352 - val_mean_squared_logarithmic_error: 0.3285
# Epoch 88/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2282 - mean_squared_logarithmic_error: 0.2275 - val_loss: 0.3356 - val_mean_squared_logarithmic_error: 0.3289
# Epoch 89/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2281 - mean_squared_logarithmic_error: 0.2273 - val_loss: 0.3328 - val_mean_squared_logarithmic_error: 0.3255
# Epoch 90/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2280 - mean_squared_logarithmic_error: 0.2278 - val_loss: 0.3331 - val_mean_squared_logarithmic_error: 0.3260
# Epoch 91/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2290 - mean_squared_logarithmic_error: 0.2283 - val_loss: 0.3344 - val_mean_squared_logarithmic_error: 0.3275
# Epoch 92/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2289 - mean_squared_logarithmic_error: 0.2280 - val_loss: 0.3352 - val_mean_squared_logarithmic_error: 0.3288
# Epoch 93/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2286 - mean_squared_logarithmic_error: 0.2284 - val_loss: 0.3339 - val_mean_squared_logarithmic_error: 0.3274
# Epoch 94/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2276 - mean_squared_logarithmic_error: 0.2301 - val_loss: 0.3340 - val_mean_squared_logarithmic_error: 0.3274
# Epoch 95/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2269 - mean_squared_logarithmic_error: 0.2260 - val_loss: 0.3357 - val_mean_squared_logarithmic_error: 0.3295
# Epoch 96/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2276 - mean_squared_logarithmic_error: 0.2269 - val_loss: 0.3355 - val_mean_squared_logarithmic_error: 0.3289
# Epoch 97/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2277 - mean_squared_logarithmic_error: 0.2278 - val_loss: 0.3358 - val_mean_squared_logarithmic_error: 0.3297
# Epoch 98/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2287 - mean_squared_logarithmic_error: 0.2283 - val_loss: 0.3358 - val_mean_squared_logarithmic_error: 0.3294
# Epoch 99/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2272 - mean_squared_logarithmic_error: 0.2270 - val_loss: 0.3351 - val_mean_squared_logarithmic_error: 0.3288
# Epoch 100/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.2263 - mean_squared_logarithmic_error: 0.2254 - val_loss: 0.3402 - val_mean_squared_logarithmic_error: 0.3345

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mean_squared_logarithmic_error')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_log_error

# assuming you have already trained and evaluated your regression ANN model
# and have obtained the predicted y values (y_pred) for X_test

# calculate MSLE
y_pred = model.predict(X_test)
msle = mean_squared_log_error(y_test,(y_pred))

# print MSLE
print("Mean Squared Logarithmic Error (MSLE): ", msle)

# plot MSLE
plt.plot(np.arange(len(y_test)), np.log(y_test+1), label='Actual')
plt.plot(np.arange(len(y_pred)), np.log(y_pred+1), label='Predicted')
plt.legend()
plt.xlabel('Data Point')
plt.ylabel('Log(Y+1)')
plt.title('LSTM: Actual vs Predicted (log scale)')
plt.show()
# Out:
# 10/10 [==============================] - 0s 7ms/step
# Mean Squared Logarithmic Error (MSLE):  0.18772539092704502

# %%
predictions = model.predict(X_test)

f, axes = plt.subplots(1, 1,figsize=(15,5))

# Our model predictions
plt.scatter(y_test,predictions)

# Perfect predictions
plt.plot(y_test,y_test,'r')

sns.despine(left=True, bottom=True)
axes.set(xlabel='Test True Y', ylabel='Model Predictions', title='Model Predictions vs Perfect Fit')
# Out:
# 10/10 [==============================] - 0s 5ms/step
# [Text(0.5, 0, 'Test True Y'),
#  Text(0, 0.5, 'Model Predictions'),
#  Text(0.5, 1.0, 'Model Predictions vs Perfect Fit')]
